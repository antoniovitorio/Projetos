# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniovitorio/Projetos/blob/master/Relatorio_impressora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import csv

# %%
data = pd.read_csv('/content/sample_data/arquivo_teste.csv',encoding = "ISO-8859-1")

# %%
data

# %%
data.rename (columns= {"User Name": "Usuario",
                        "Type": "Processo",
                       "Print Pages": "Total de Paginas",
                       "Time": "Hora",
                       "Date": "Data"},inplace = True)

# %%
data
# Out:
#     Id        Processo  ...      Hora Total de Paginas
# 0    1  Print(Network)  ...  09:01:50                1
# 1    2  Print(Network)  ...  09:02:10                1
# 2    3  Print(Network)  ...  09:02:13                1
# 3    4  Print(Network)  ...  09:02:17                1
# 4    5  Print(Network)  ...  11:20:02               25
# 5    6  Print(Network)  ...  11:22:28                1
# 6    7  Print(Network)  ...  11:22:41                1
# 7    8  Print(Network)  ...  13:26:28                2
# 8    9  Print(Network)  ...  13:28:13                2
# 9   10            Copy  ...  13:30:15                1
# 10  11  Print(Network)  ...  13:30:41                2
# 11  12  Print(Network)  ...  13:30:57                2
# 12  13  Print(Network)  ...  14:18:35                1
# 13  14  Print(Network)  ...  14:18:55                1
# 14  15  Print(Network)  ...  14:18:58                1
# 15  16  Print(Network)  ...  14:19:02                1
# ...

# %%
data [["Usuario","Total de Paginas","Processo","Data","Hora"]]
# Out:
#               Usuario Total de Paginas        Processo        Data      Hora
# 0     brendo.mendonca                1  Print(Network)  19/08/2020  09:01:50
# 1     brendo.mendonca                1  Print(Network)  19/08/2020  09:02:10
# 2     brendo.mendonca                1  Print(Network)  19/08/2020  09:02:13
# 3     brendo.mendonca                1  Print(Network)  19/08/2020  09:02:17
# 4        damiao.silva               25  Print(Network)  19/08/2020  11:20:02
# 5        damiao.silva                1  Print(Network)  19/08/2020  11:22:28
# 6        damiao.silva                1  Print(Network)  19/08/2020  11:22:41
# 7        damiao.silva                2  Print(Network)  19/08/2020  13:26:28
# 8        damiao.silva                2  Print(Network)  19/08/2020  13:28:13
# 9              Public                1            Copy  19/08/2020  13:30:15
# 10       damiao.silva                2  Print(Network)  19/08/2020  13:30:41
# ...
