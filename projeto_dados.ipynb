# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniovitorio/Projetos/blob/master/projeto_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel("/content/controle_de_abacates.xlsx")

# %%
planilha = pd.read_excel("/content/controle_de_abacates.xlsx")

# %%
planilha

# %%
planilha.info()

# %%
planilha.describe()

# %%
planilha.plot("data","preco_medio")

# %%
planilha.plot("data", "volume_total")
